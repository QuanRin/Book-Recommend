# %%
import requests
from bs4 import BeautifulSoup
import time
import time
import schedule
banks_hose = ['ACB', 'BID', 'CTG', 'EIB', 'HDB', 'MBB', 'MSB',
              'OCB', 'SHB', 'SSB', 'STB', 'TCB', 'TPB', 'VCB', 'VIB', 'VPB']
banks_hnx = ['NVB', 'BAB']
data = {}


def get_data_from_web(bank):
    print('bank', bank)
    url = f'https://simplize.vn/co-phieu/{bank}/lich-su-gia'
    response = requests.get(url)
    data = {}
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        tbody = soup.find('tbody', class_='simplize-table-tbody')
        if tbody:
            tr_simplize_table_row = tbody.find_all(
                'tr', class_='simplize-table-row')
            h6_css_cvilom_today = tr_simplize_table_row[0].find_all(
                'h6', class_='css-cvilom')
            h6_css_cvilom_yesterday = tr_simplize_table_row[1].find_all(
                'h6', class_='css-cvilom')
            stockHistory = {}
            today = h6_css_cvilom_today[0].text.strip()
            stockHistory['open'] = h6_css_cvilom_today[1].text.strip()
            stockHistory['high'] = h6_css_cvilom_today[2].text.strip()
            stockHistory['low'] = h6_css_cvilom_today[3].text.strip()
            stockHistory['close_yesterday'] = h6_css_cvilom_yesterday[4].text.strip()
            stockHistory['volume_yesterday'] = h6_css_cvilom_yesterday[5].text.strip()
            data[today] = stockHistory
    return data


def crawl(banks_hose, banks_hnx):
    for bank in banks_hose:
        data[bank] = {}
        data[bank] = get_data_from_web(bank)
    for bank in banks_hnx:
        data[bank] = {}
        data[bank] = get_data_from_web(bank)
    print(data)
    return data


schedule.every(1).minutes.do(crawl, banks_hose=banks_hose, banks_hnx=banks_hnx)
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,000', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '', 'high': '', 'low': '', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'11/04/2024': {'open': '23,700', 'high': '24,000', 'low': '23,500', 'close_yesterday': '23,950', 'volume_yesterday': '-'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '23,950', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,350', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'11/04/2024': {'open': '14,450', 'high': '14,600', 'low': '14,350', 'close_yesterday': '14,650', 'volume_yesterday': '2,464,000'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '', 'high': '', 'low': '', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '45,500', 'low': '45,200', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,100', 'low': '22,900', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'11/04/2024': {'open': '10,500', 'high': '10,500', 'low': '10,200', 'close_yesterday': '10,500', 'volume_yesterday': '333,500'}}, 'BAB': {'11/04/2024': {'open': '12,500', 'high': '12,500', 'low': '12,400', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,700', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '18,200', 'high': '18,250', 'low': '18,050', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'12/04/2024': {'open': '24,000', 'high': '24,100', 'low': '23,650', 'close_yesterday': '24,000', 'volume_yesterday': '5,637,400'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '24,250', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,300', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'12/04/2024': {'open': '14,650', 'high': '14,800', 'low': '14,500', 'close_yesterday': '14,600', 'volume_yesterday': '524,300'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '22,100', 'high': '22,200', 'low': '22,000', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '46,250', 'low': '45,100', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,150', 'low': '22,850', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'12/04/2024': {'open': '10,300', 'high': '10,300', 'low': '10,200', 'close_yesterday': '10,300', 'volume_yesterday': '82,800'}}, 'BAB': {'12/04/2024': {'open': '12,600', 'high': '12,600', 'low': '12,500', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,700', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '18,200', 'high': '18,250', 'low': '18,050', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'12/04/2024': {'open': '24,000', 'high': '24,100', 'low': '23,650', 'close_yesterday': '24,000', 'volume_yesterday': '5,637,400'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '24,250', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,300', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'12/04/2024': {'open': '14,650', 'high': '14,800', 'low': '14,500', 'close_yesterday': '14,600', 'volume_yesterday': '524,300'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '22,100', 'high': '22,200', 'low': '22,000', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '46,250', 'low': '45,100', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,150', 'low': '22,850', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'12/04/2024': {'open': '10,300', 'high': '10,300', 'low': '10,200', 'close_yesterday': '10,300', 'volume_yesterday': '82,800'}}, 'BAB': {'12/04/2024': {'open': '12,600', 'high': '12,600', 'low': '12,500', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,700', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '18,200', 'high': '18,250', 'low': '18,050', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'12/04/2024': {'open': '24,000', 'high': '24,100', 'low': '23,650', 'close_yesterday': '24,000', 'volume_yesterday': '5,637,400'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '24,250', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,300', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'12/04/2024': {'open': '14,650', 'high': '14,800', 'low': '14,500', 'close_yesterday': '14,600', 'volume_yesterday': '524,300'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '22,100', 'high': '22,200', 'low': '22,000', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '46,250', 'low': '45,100', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,150', 'low': '22,850', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'12/04/2024': {'open': '10,300', 'high': '10,300', 'low': '10,200', 'close_yesterday': '10,300', 'volume_yesterday': '82,800'}}, 'BAB': {'12/04/2024': {'open': '12,600', 'high': '12,600', 'low': '12,500', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,700', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '18,200', 'high': '18,250', 'low': '18,050', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'12/04/2024': {'open': '24,000', 'high': '24,100', 'low': '23,650', 'close_yesterday': '24,000', 'volume_yesterday': '5,637,400'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '24,250', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,300', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'12/04/2024': {'open': '14,650', 'high': '14,800', 'low': '14,500', 'close_yesterday': '14,600', 'volume_yesterday': '524,300'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '22,100', 'high': '22,200', 'low': '22,000', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '46,250', 'low': '45,100', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,150', 'low': '22,850', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'12/04/2024': {'open': '10,300', 'high': '10,300', 'low': '10,200', 'close_yesterday': '10,300', 'volume_yesterday': '82,800'}}, 'BAB': {'12/04/2024': {'open': '12,600', 'high': '12,600', 'low': '12,500', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,700', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '18,200', 'high': '18,250', 'low': '18,050', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'12/04/2024': {'open': '24,000', 'high': '24,100', 'low': '23,650', 'close_yesterday': '24,000', 'volume_yesterday': '5,637,400'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '24,250', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,300', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'12/04/2024': {'open': '14,650', 'high': '14,800', 'low': '14,500', 'close_yesterday': '14,600', 'volume_yesterday': '524,300'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '22,100', 'high': '22,200', 'low': '22,000', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '46,250', 'low': '45,100', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,150', 'low': '22,850', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'12/04/2024': {'open': '10,300', 'high': '10,300', 'low': '10,200', 'close_yesterday': '10,300', 'volume_yesterday': '82,800'}}, 'BAB': {'12/04/2024': {'open': '12,600', 'high': '12,600', 'low': '12,500', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB
# bank TCB
# bank TPB
# bank VCB
# bank VIB
# bank VPB
# bank NVB
# bank BAB
# {'ACB': {'12/04/2024': {'open': '27,200', 'high': '27,400', 'low': '27,000', 'close_yesterday': '27,150', 'volume_yesterday': '11,286,500'}}, 'BID': {'12/04/2024': {'open': '53,000', 'high': '53,500', 'low': '52,800', 'close_yesterday': '53,000', 'volume_yesterday': '2,276,400'}}, 'CTG': {'12/04/2024': {'open': '33,800', 'high': '34,700', 'low': '33,650', 'close_yesterday': '33,700', 'volume_yesterday': '4,179,700'}}, 'EIB': {'12/04/2024': {'open': '18,200', 'high': '18,250', 'low': '18,050', 'close_yesterday': '18,150', 'volume_yesterday': '11,286,700'}}, 'HDB': {'12/04/2024': {'open': '24,000', 'high': '24,100', 'low': '23,650', 'close_yesterday': '24,000', 'volume_yesterday': '5,637,400'}}, 'MBB': {'12/04/2024': {'open': '23,850', 'high': '24,250', 'low': '23,750', 'close_yesterday': '23,750', 'volume_yesterday': '9,011,600'}}, 'MSB': {'12/04/2024': {'open': '14,350', 'high': '14,450', 'low': '14,300', 'close_yesterday': '14,350', 'volume_yesterday': '-'}}, 'OCB': {'12/04/2024': {'open': '14,650', 'high': '14,800', 'low': '14,500', 'close_yesterday': '14,600', 'volume_yesterday': '524,300'}}, 'SHB': {'12/04/2024': {'open': '11,200', 'high': '11,200', 'low': '11,100', 'close_yesterday': '11,100', 'volume_yesterday': '12,380,200'}}, 'SSB': {'12/04/2024': {'open': '22,100', 'high': '22,200', 'low': '22,000', 'close_yesterday': '22,050', 'volume_yesterday': '2,017,000'}}, 'STB': {'12/04/2024': {'open': '29,100', 'high': '29,400', 'low': '29,050', 'close_yesterday': '28,850', 'volume_yesterday': '10,462,800'}}, 'TCB': {'12/04/2024': {'open': '45,450', 'high': '46,250', 'low': '45,100', 'close_yesterday': '45,100', 'volume_yesterday': '11,371,200'}}, 'TPB': {'12/04/2024': {'open': '18,350', 'high': '18,400', 'low': '18,250', 'close_yesterday': '18,350', 'volume_yesterday': '-'}}, 'VCB': {'12/04/2024': {'open': '94,500', 'high': '94,500', 'low': '93,800', 'close_yesterday': '94,000', 'volume_yesterday': '778,000'}}, 'VIB': {'12/04/2024': {'open': '23,100', 'high': '23,150', 'low': '22,850', 'close_yesterday': '22,900', 'volume_yesterday': '-'}}, 'VPB': {'12/04/2024': {'open': '19,400', 'high': '19,600', 'low': '19,400', 'close_yesterday': '19,350', 'volume_yesterday': '-'}}, 'NVB': {'12/04/2024': {'open': '10,300', 'high': '10,300', 'low': '10,200', 'close_yesterday': '10,300', 'volume_yesterday': '82,800'}}, 'BAB': {'12/04/2024': {'open': '12,600', 'high': '12,600', 'low': '12,500', 'close_yesterday': '12,500', 'volume_yesterday': '-'}}}
# bank ACB
# bank BID
# bank CTG
# bank EIB
# bank HDB
# bank MBB
# bank MSB
# bank OCB
# bank SHB
# bank SSB
# bank STB

# %%
# !pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.2.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Downloading schedule-1.2.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.2.1
# WARNING: Ignoring invalid distribution -cikit-learn (d:\wpsystem\s-1-5-21-3269375078-2600015948-3888818519-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\wpsystem\s-1-5-21-3269375078-2600015948-3888818519-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\wpsystem\s-1-5-21-3269375078-2600015948-3888818519-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\wpsystem\s-1-5-21-3269375078-2600015948-3888818519-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\wpsystem\s-1-5-21-3269375078-2600015948-3888818519-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\wpsystem\s-1-5-21-3269375078-2600015948-3888818519-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
